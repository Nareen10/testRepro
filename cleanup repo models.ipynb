# %% [markdown]
# ### WML Credentials

# %%
wml_credentials = {
  "url": "https://ibm-watson-ml-svt.stage1.mybluemix.net",
#   "username": "ba517342-a2fa-48d7-a66b-cc0532e6d29a",
#   "password": "68fba1c3-dd96-4dd1-b44e-3803d96af8d2",
#   "instance_id": "e3499b29-3ddd-4835-b3ae-22eef36c592e"
    "username": "e518909a-d79f-4314-9c7b-a1cf9c6cbec9",
  "password": "76091a53-67f3-48fc-9b6a-437c9a03d2b9",
  "instance_id": "0c474481-2a5a-4b6a-b49b-7486f914e138"
}

# %% [markdown]
# ### Install WML API Client

# %%
# !pip install --upgrade watson-machine-learning-client==0.3.701

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
client = WatsonMachineLearningAPIClient(wml_credentials)

# %% [markdown]
# ### Delete Model Definitions

# %%
from IPython.utils import io
with io.capture_output() as captured:
    client.repository.list_definitions()

definitions_list=str(captured.stdout)

# %%
definitionsGuid = []
if (definitions_list.count('\n') > 3):
    parsed_definitions_list = definitions_list.rsplit("\n",2)[0].split("\n",2)[2]
    for line in parsed_definitions_list.splitlines():
        guid = line.split(" ",1)[0]
        definitionsGuid.append(guid)
    try:
        for i in definitionsGuid:
             client.repository.delete(i)
    except BaseException as e:
        print ("Could not delete: " + i)
        pass

# %% [markdown]
# ### Delete Models

# %%
with io.capture_output() as captured:
    client.repository.list_definitions()

definitions_list=str(captured.stdout)

# %%
# import json
# deployment_data = str(client.deployments.get_details())
# deployment_data = json.load(deployment_data)
client.deployments.get_details()
# Out:
# {'count': 197,
#  'resources': [{'entity': {'deployed_version': {'guid': '535ce796-66b9-49f1-a6be-a45d3de023d9',
#      'url': 'https://ibm-watson-ml-svt.stage1.mybluemix.net/v3/ml_assets/models/580c593b-9ff7-4d9b-a734-cc6636e3d29e/versions/535ce796-66b9-49f1-a6be-a45d3de023d9'},
#     'description': 'Online Deployment',
#     'model_type': 'wml-1.1',
#     'name': 'onlineTestDeployment',
#     'published_model': {'author': {'email': 'testuser@mail.com',
#       'name': 'test user'},
#      'created_at': '2018-02-15T20:54:06.110Z',
#      'guid': '580c593b-9ff7-4d9b-a734-cc6636e3d29e',
#      'name': 'onlineTestModel',
#      'url': 'https://ibm-watson-ml-svt.stage1.mybluemix.net/v3/wml_instances/0c474481-2a5a-4b6a-b49b-7486f914e138/published_models/580c593b-9ff7-4d9b-a734-cc6636e3d29e'},
#     'runtime_environment': 'spark-2.0',
# ...

# %%
client.repository.list_models()
# Out:
# ------------------------------------  ----------------------------------------------  ------------------------  -----------------  -----
# GUID                                  NAME                                            CREATED                   FRAMEWORK          TYPE
# 485d3abe-b688-4d8a-9f8c-6c1be895df78  WML-105-1-Model-LinearRegression-metrodata      2018-02-14T16:44:39.838Z  mllib-2.0          model
# befe9ae2-b4e6-49fb-b323-c4218e1d6960  WML-105-3-Model-Kmeans-GoSalesNB                2018-02-14T16:49:07.438Z  mllib-2.0          model
# 0e2490d2-46bf-42b6-b357-01f50de3ab2c  WML-105-2-Model-LogisticRegression-words        2018-02-14T17:36:47.717Z  mllib-2.0          model
# 8d79fd4c-1a1d-4bae-bf5d-a88f4e9a7abc  WML-105-3-Model-Kmeans-GoSalesNB                2018-02-14T17:39:22.003Z  mllib-2.0          model
# f71d8fb8-fad4-4cae-a030-82d4388a4362  WML-105-1-Model-LinearRegression-metrodata      2018-02-14T19:44:21.524Z  mllib-2.0          model
# ...

# %%
with io.capture_output() as captured:
    client.repository.list_definitions()
definitions_list = str(captured.stdout)

# %%
new_definitions_list = definitions_list.rsplit("\n",2)[0].split("\n",2)[2]

# %%
print (table_definition)

# %%
print (new_definitions_list)

# %%
with io.capture_output() as captured:
    client.repository.list_models()
models_list = str(captured.stdout)

# %%
if (models_list.count('\n') >3):
    print (models_list.count("\n"))
    new_models_list = models_list.rsplit("\n",2)[0].split("\n",2)[2]

# %%
repolist = ['8466acba-b706-4ad9-848a-b28282b69a4b','113e35d5-424b-422e-8365-5e30206ba62c','02a4d44a-477d-46d2-8aac-433fd9632ca2','0e0f1105-c98e-4c0b-97bc-3ac5f2f36c23','ee18176d-c534-4cba-a3cd-9b6ab99c0bb9','7abf92a1-5251-4bb5-9b1c-ea6761b3e1fb','194ee0c6-486b-48bb-a193-4ff133cbf0cc','39e32158-5ac2-43e4-927d-6d146b6cf329','a285919e-7aac-4a52-af97-4342a4b9ff5f','ec928b1e-97b6-4686-b6e8-e52a4bd29fa8','9f24673a-a891-4aba-a067-c13128cd155e','3cd152fd-b55d-4d28-af34-50fbfd032b1e','4cfdf0dc-8038-4a8c-a548-4e6f17451434','154752ff-ca74-47f8-a458-4d41ac7eb5d1','f82ff921-9235-47bd-b27f-db128fb9e35d','1daaeffa-4090-4e49-b0b3-74aecfc2c6cf','9dcafc36-9978-4b69-abf6-90766d18af8a','adf9e122-04a6-413c-ada0-83d913cad448','92cddc36-2cb6-483a-93f5-b0f407a9b6d9','991ffb2f-42d0-4a9e-9674-abce3a18fc70','abf6aece-b2ac-41a9-8345-2deccace0b9b','cc4254ab-4176-4d05-8fad-22705c15732d','4e2f0020-2175-4cd8-8a7f-50f26e87b829','650c985b-7ffb-422b-8f9d-0ab229555dae','7a91dcdc-4ffc-448c-92ef-5f32a5ccf1e2','901cf130-fc49-4853-aa9f-452cff37bdc1','2bdd5171-c2dc-48db-960d-7fb0766688c4','50063151-0552-4b5c-a79e-b911f8b95660','7ff9401c-a76d-477d-9e60-9e337820158a','e4b55230-49bf-4a2d-a16b-99da0bbe92e1','2ff0e210-9581-4780-922b-d29ec7974f7e','dd859f02-81eb-4b60-b61a-a4c67f4643eb','bf365df7-83a7-4173-acb4-bcb7d4578dc5','01ebaaa0-1eb8-48d0-a170-004a08eb3808','4c40864e-af21-4ac6-90d0-443b3c89974c','e90dc7eb-a5e0-45d3-bd85-55b62c5b989a','44c08849-e0ee-4b55-9bec-ec5967099c0f','16616b11-1b20-4d5f-b405-857f5dce4f77','f63e0fb5-7d02-412e-b18e-6aa59bf16fa2','ac2f71f9-15de-4f33-8662-409c834d644e','d005e103-70e8-476f-a6f8-67cc5b04cbbe','83c64b84-1d52-4523-ab9a-1de5aae51d98','2da3a3ec-5ed8-429e-a617-85794e3493df','0f8ddbf6-a9c0-4fed-8ac9-0671efe2e2a4','c9fde1ea-e44a-417b-979e-02d4963a9433','f3b6f16e-
a1c9-0f1e2b8006ed','22a85c3f-d1ff-4e87-9f3f-f16d1ae708c1','04001d8f-12b3-446e-9672-c0dc6c7807b0','2d4cc855-5175-4743-b2cd-6bd7d28a8940','937e2a08-6b43-437b-9df7-6ed4b9d72da4','2a4783b8-5c69-4b28-a49d-9a1a66e96234','bff6244b-3dd1-4025-bf3d-6dc878e22e58','57664650-b856-4fe0-a5a2-a079eecb6442','d9e0d5ae-304f-46a2-8062-bcc3132e3add','33631ce5-5dd5-4819-a109-8b77a3bcca06','dbee2645-5d69-4384-b0a2-1960052d757e','c2c52947-46fa-4220-985d-bb9f74a97f56','fce063ca-2af2-4b20-a31f-433e8a70be51','1e7d31d4-a714-465c-96e9-c564fb4fea11','5392c54c-0bed-4874-81ad-9f3155cf22e8','d367eb77-38c6-4128-bd2a-bc0a6acb6168','72cca4a1-60d0-47d1-8c6b-c326d2b20ee0','d919b466-0ddc-4830-bf22-0633596f7d5d','ed1a4aae-c3cc-4a9b-a412-eae69b5e9ec5','28861e0a-835e-46c2-849c-503bff7122b7','52c4889f-1e92-4fe5-86ca-da67a675cb92','d58c5dda-83e2-4711-8bca-ce4bde47fd85','14922e0e-ced0-476b-b202-9014c0f06546','b34ac9f9-6d90-4313-b31f-16f456541118','3a1f9d15-af9b-4396-bc6e-b10128ea7a3b','59e0b552-27a0-4ee7-8000-8937b1c17126','8de7718a-2328-42f3-8755-f0292dc8d7dc','f66a16c0-0249-4b16-86ac-18402870882c','41674129-7988-423d-bb18-8532c5e878dc','d93d3fb9-0a6a-4fd4-81f2-56825b87b1c1','e8803e62-6861-4b40-a357-74e78fe0dd97','38a00a60-703f-437b-9c1a-4eb62bb5eed3','f43b0dc2-634f-4a94-b5d5-718f79f3a502','882fac35-b682-454d-b2ae-babe0954755f','ffe4819b-b1dc-4ec6-bc03-256c169c4bb1','62a9e43c-507b-4eb9-b7e0-dfdd5e85687c','77dbc70c-469b-47ff-9a42-7b3cbae7fb70','9b534466-0191-4cbf-a56a-d8546da4062a']

# %%
for x in repolist:
    client.repository.delete(x)

# %%
deploymentlist = [s.split() for s in os.open(client.deployments.list()).read().splitlines()]

# %%
# Out:
# ------------------------------------  ------------------------------------  -----------------  ---------  --------------------
# GUID (experiment)                     GUID (run)                            NAME (experiment)  STATE      CREATED
# 84ac273e-a4e5-436e-a771-00a80249ab9e  c9a2c8ea-0e3a-4cfe-b883-efbbaa6f4202  experimentTest     completed  2018-02-11T17:52:22Z
# daf36d5e-d04c-4742-bea4-b2c063db8550  0b9afdcc-93c6-4f32-8027-01c47124d205  experimentTest1    completed  2018-02-11T16:55:39Z
# ecebb4b3-63d3-4800-9058-b14f7877878e  fe560880-7978-4425-b62c-1e63b83c5bf5  experimentTest     completed  2018-02-11T18:51:39Z
# ------------------------------------  ------------------------------------  -----------------  ---------  --------------------

# %%
print(list["GUID (experiment)"])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-281-759487c803dd> in <module>()
# ----> 1 print(list["GUID (experiment)"])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
-4207-4979-8568-ec9f9b54248c','c2cc38e3-3ec8-4850-bb24-32855c70fa9d','c30517e2-7344-408f-89eb-e89d5d7a9660','c549659e-862f-4467-94d8-b887024c3d06','c5f3a2ab-a443-4891-a103-d68004cad315','c74a0f47-08b8-41a7-b0d6-9c25ee6ed847','c7a6011f-e1d3-4e33-ae71-4f41b4dbd567','cdd46a81-ed15-4776-b75c-0289d9e90250','cf91695a-8793-4449-bea5-31c437232584','d12734ed-95cf-4a54-9e37-7331ce224301','d42f8c22-b129-4238-93c9-9b01bc4bb0aa','d549595c-d6c9-45e2-9683-8d87c019b99c','d775b723-5c65-4842-8f22-86fe78151f17','d888e8e7-7cad-42ac-8db9-de622b9f2e44','d9585827-a46d-4223-ac79-f06233f20493','d9606eb2-64f2-4123-b1b6-4f16d5669ab1','d9840658-d4a0-4eaa-8206-960aaea67bbf','dbf73913-2aa2-46f4-981d-3be339a0ec37','dcca02a8-5be0-4bb2-ae1d-928a22a39065','dde230bd-15dc-4106-a06a-eac7bcaefd35','df70e30e-f47f-4138-a558-fe0bc161e5fe','e0ec8af0-54bb-40d7-9d3d-789d96c264a7','e2a92cb1-1195-4c0e-bb28-3748316c07b8','e3e79c2b-5ed9-4e89-879d-ab1686cca4bd','e408e699-4dfa-4362-bce4-769ffc46c47e','e426a2e3-7e0e-43b4-946b-6040d7f180ed','e71c307c-782f-4fca-b792-11b811d0ba9c','e73bafe0-df15-4f6a-80e0-6cc73bfb1a40','e88aa52f-3192-40be-a962-4ac7de56bfd2','e96e18af-0d4d-41ba-9040-0d6fd4b0ec5c','e9f003cf-93c1-4382-b176-2816bae287cc','eaff0f2c-ee83-4046-972b-3a330ce54737','ee08779f-cd9d-4740-b44c-6e03dd28b195','eeb37ce4-8765-4a0a-a722-2579dd1d7dc3','ef34ff38-4ca5-4a18-89ae-1050eb6ecf05','f0719791-72f4-43fe-9e3d-f07c956cf038','f2f0b27a-8b66-48bc-995b-7a079da549ce','f4c5ab89-ad50-4007-8939-2b0463098fa1','f5145337-eb93-4910-9cac-f270530127c1','f54b1ebe-d3d1-4aaf-923e-536721600acb','f570cd07-2b2b-4708-b43c-3d4e2b30f482','f60ab551-c0bb-486d-bf64-bd272077a861','f7533cda-1029-45eb-902c-78c259bb18ed','f918435c-2a51-4f5a-9a2b-9e04382a4e71','fbd1233a-196d-4061-8366-30803c30ea71','ff251871-cb48-4254-a07b-088fbd3bfdab']

# %%
for y in deploylist:
    client.deployments.delete(y)
#need to handle exceptions from client call

# %%
client.experiments.list()

# %%
from IPython.utils import io
with io.capture_output() as captured:
    client.experiments.list()

experiments_list=str(captured.stdout)

# %%
new_experiment_list = experiments_list.rsplit("\n",2)[0].split("\n",2)[2]

# %%
print(new_experiment_list)

# %%
newGuid = []
for line in new_experiment_list.splitlines():
    guid = line.split(" ",1)[0]
    newGuid.append(str(guid))

# %%
for y in newGuid:
    client.experiments.

# %%
experiments_guid = [line[0] for line in new_experiment_list]

# %%
print (experiments_guid)

# %%
with open(client.experiments.list()) as f:
    lines = f.readlines()

# %%
client.experiments.delete(experiment_run_id)

# %%
client.repository.delete(definition_uid)
